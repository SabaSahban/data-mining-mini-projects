# %% [markdown]
# <h1 align=center style="line-height:300%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سری اول تمارین عملی درس داده کاوی
# </font>
# </h1>
# <h3 align=center style="line-height:100%;font-family:vazir;color:#0099cc">
# استاد درس: دکتر مریم امیر مزلقانی
# </h3>
# <h5 align=center style="font-size: 20px;line-height:100%;font-family:vazir;color:#0099cc">
# طراح تمرین عملی: پوریا جمیع
# </h5>
# <p align=center style="font-size: 16;line-height:100%;font-family:vazir;color:#0099cc">
#     <a href="mailto:Aut.DataMining.Fall@gmail.com">Aut.DataMining.Fall@gmail.com</a>
# </p>

# %% [markdown]
# <div dir="rtl">
# <p align=right style="font-size: 16;line-height:100%;font-family:vazir;color:yellow">
# لطفا خواسته های تمرین را در بخش خودش انجام دهید.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# خواندن کتابخانه ها
# </h3>
# </div>

# %%
# TO-DO
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/sabasahban/.pyenv/versions/3.10.6/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sabasahban/.pyenv/versions/3.10.6/lib/python3.10/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/sabasahban/.pyenv/versions/3.10.6/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/sabasahban/.pyenv/versions/3.10.6/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sabasahban/.pyenv/versions/3.10.6/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/sabasahban/.pyenv/versions/3.10.6/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# دریافت مجموعه داده
# </h3>
# </div>

# %%
# load data
import pandas as pd
data = pd.read_excel('worldcities.xlsx')
data[data.population.isna()]
# Out:
#            ville ville_ascii      lat       lng              pays iso2 iso3  \
# 30     Abakaliki   Abakaliki   6.3249    8.1137           Nigeria   NG  NGA
# 240    Adamstown   Adamstown -25.0667 -130.0833  Pitcairn Islands   PN  PCN
# 331        Agago       Agago   2.9847   33.3306            Uganda   UG  UGA
# 484        Aileu       Aileu  -8.7281  125.5664       Timor-Leste   TL  TLS
# 490    Aïn Defla   Ain Defla  36.2583    1.9583           Algeria   DZ  DZA
# ...          ...         ...      ...       ...               ...  ...  ...
# 44199    Zaječar     Zajecar  43.9042   22.2847            Serbia   RS  SRB
# 44301      Zavrč       Zavrc  46.3917   16.0497          Slovenia   SI  SVN
# 44364     Žetale      Zetale  46.2750   15.7939          Slovenia   SI  SVN
# 44547   Žitorađa    Zitorada  43.1833   21.7167            Serbia   RS  SRB
# 44641  Žužemberk   Zuzemberk  45.8339   14.9292          Slovenia   SI  SVN
#
#        admin_nom  capital  population            id
# 30        Ebonyi    admin         NaN  1.566880e+09
# 240          NaN  primary         NaN  1.612000e+09
# 331        Agago    admin         NaN  1.800321e+09
# 484        Aileu    admin         NaN  1.626767e+09
# 490    Aïn Defla    admin         NaN  1.012656e+09
# ...          ...      ...         ...           ...
# 44199    Zaječar    admin         NaN  1.688565e+09
# 44301      Zavrč    admin         NaN  1.705478e+09
# 44364     Žetale    admin         NaN  1.705942e+09
# 44547   Žitorađa    admin         NaN  1.688262e+09
# 44641  Žužemberk    admin         NaN  1.705028e+09
#
# [306 rows x 11 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# حذف و تغییر نام ستون ها
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ستون‌های
# <code>id</code>،
# <code>‌capital</code>،
# <code>ville_ascii</code>
# و
# <code>admin_nom</code>
#  را از دیتافریم حذف نمایید.
# سپس نام ستون‌های
# <code>ville</code>
# و
# <code>pays</code>
#  که به زبان فرانسوی نامگذاری شده‌اند را به ترتیب به
# <code>city</code>
# و
# <code>country</code>
# تغییر دهید.
# </font>
# </p>
# </div>

# %%
# drop and rename
columns_to_remove = ["id", "capital", "ville_ascii", "admin_nom"]
data.drop(columns=columns_to_remove, inplace=True)
data.rename(columns={"ville": "city", "pays": "country"}, inplace=True)

data
# Out:
#              city      lat       lng      country iso2 iso3  population
# 0        A Coruña  43.3667   -8.3833        Spain   ES  ESP    245468.0
# 1        A Yun Pa  13.3939  108.4408      Vietnam   VN  VNM     53720.0
# 2        Aabenraa  55.0444    9.4181      Denmark   DK  DNK     16401.0
# 3          Aachen  50.7756    6.0836      Germany   DE  DEU    249070.0
# 4          Aadorf  47.4939    8.8975  Switzerland   CH  CHE      9036.0
# ...           ...      ...       ...          ...  ...  ...         ...
# 44662     Żychlin  52.2453   19.6236       Poland   PL  POL      9021.0
# 44663    Żyrardów  52.0500   20.4333       Poland   PL  POL     39374.0
# 44664    Zyryanka  65.7360  150.8900       Russia   RU  RUS      3627.0
# 44665  Zyryanovsk  49.7453   84.2548   Kazakhstan   KZ  KAZ     49658.0
# 44666      Żywiec  49.6892   19.2058       Poland   PL  POL     30334.0
#
# [44667 rows x 7 columns]

# %% [markdown]
# |<div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# فیلتر کردن داده ها
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# شهر‌های با جمعیت اکیدا کمتر از ۱ میلیون نفر  را از دیتافریم حذف کرده و سپس نوع داده‌های ستون
# <code>population</code>
#  را از
#  <code>float</code>
#   به
#   <code>int32</code>
#    تبدیل نمایید.
# </p>
# </div>

# %%
# filter dat# filter data
data = data[data['population'] >= 1000000]
data
# Out:
#             city      lat       lng               country iso2 iso3  \
# 19           Aba   5.1167    7.3667               Nigeria   NG  NGA
# 83       Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV
# 121    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE
# 131        Abuja   9.0667    7.4833               Nigeria   NG  NGA
# 169        Accra   5.5500   -0.2000                 Ghana   GH  GHA
# ...          ...      ...       ...                   ...  ...  ...
# 44496  Zhumadian  32.9773  114.0253                 China   CN  CHN
# 44506    Zhuzhou      NaN  113.1469                 China   CN  CHN
# 44511       Zibo  36.7831  118.0497                 China   CN  CHN
# 44517     Zigong  29.3498  104.7645                 China   CN  CHN
# 44629      Zunyi  27.7050  106.9336                 China   CN  CHN
#
#        population
# 19      1530000.0
# 83      4980000.0
# 121     1483000.0
# 131     3770000.0
# 169     2388000.0
# ...           ...
# 44496   7231234.0
# 44506   4020800.0
# 44511   2631647.0
# 44517   2678899.0
# 44629   6606675.0
#
# [776 rows x 7 columns]

# %%
# change type population
data = data.copy()
data['population'] = data['population'].astype('int32')
data
# Out:
#             city      lat       lng               country iso2 iso3  \
# 19           Aba   5.1167    7.3667               Nigeria   NG  NGA
# 83       Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV
# 121    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE
# 131        Abuja   9.0667    7.4833               Nigeria   NG  NGA
# 169        Accra   5.5500   -0.2000                 Ghana   GH  GHA
# ...          ...      ...       ...                   ...  ...  ...
# 44496  Zhumadian  32.9773  114.0253                 China   CN  CHN
# 44506    Zhuzhou      NaN  113.1469                 China   CN  CHN
# 44511       Zibo  36.7831  118.0497                 China   CN  CHN
# 44517     Zigong  29.3498  104.7645                 China   CN  CHN
# 44629      Zunyi  27.7050  106.9336                 China   CN  CHN
#
#        population
# 19        1530000
# 83        4980000
# 121       1483000
# 131       3770000
# 169       2388000
# ...           ...
# 44496     7231234
# 44506     4020800
# 44511     2631647
# 44517     2678899
# 44629     6606675
#
# [776 rows x 7 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# کار با داده های تکراری و گم شده
# </h3>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# نخست ردیف‌های تکراری دیتافریم و سپس ردیف‌هایی که بیش از یک مورد (۲ مورد و بیش‌تر) از اطلاعات آن‌ها گم‌شده است را از دیتافریم حذف نمایید.
# </p>
# </div>

# %%
# remove duplicated and missed values
data = data.drop_duplicates()
data = data.dropna(thresh=data.shape[1] - 1)
data
# Out:
#             city      lat       lng               country iso2 iso3  \
# 19           Aba   5.1167    7.3667               Nigeria   NG  NGA
# 83       Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV
# 121    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE
# 131        Abuja   9.0667    7.4833               Nigeria   NG  NGA
# 169        Accra   5.5500   -0.2000                 Ghana   GH  GHA
# ...          ...      ...       ...                   ...  ...  ...
# 44496  Zhumadian  32.9773  114.0253                 China   CN  CHN
# 44506    Zhuzhou      NaN  113.1469                 China   CN  CHN
# 44511       Zibo  36.7831  118.0497                 China   CN  CHN
# 44517     Zigong  29.3498  104.7645                 China   CN  CHN
# 44629      Zunyi  27.7050  106.9336                 China   CN  CHN
#
#        population
# 19        1530000
# 83        4980000
# 121       1483000
# 131       3770000
# 169       2388000
# ...           ...
# 44496     7231234
# 44506     4020800
# 44511     2631647
# 44517     2678899
# 44629     6606675
#
# [767 rows x 7 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# پر کردن داده های گم‌شده
# </h3>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# برای مقادیر گم شده در ستون های
# <code>lat</code>
# و
# <code>lng</code>
# ،
# میانگین همان ستون را در
# <ins><strong>همان کشور</strong></ins>
# پر کنید
# </p>
# </div>

# %%
# fill the missing values by their country 
data['lat'] = data.groupby('country')['lat'].transform(lambda x: x.fillna(x.mean()))
data['lng'] = data.groupby('country')['lng'].transform(lambda x: x.fillna(x.mean()))
data
# Out:
#             city        lat       lng               country iso2 iso3  \
# 19           Aba   5.116700    7.3667               Nigeria   NG  NGA
# 83       Abidjan   5.316700   -4.0333         Côte d'Ivoire   CI  CIV
# 121    Abu Dhabi  24.466700   54.3667  United Arab Emirates   AE  ARE
# 131        Abuja   9.066700    7.4833               Nigeria   NG  NGA
# 169        Accra   5.550000   -0.2000                 Ghana   GH  GHA
# ...          ...        ...       ...                   ...  ...  ...
# 44496  Zhumadian  32.977300  114.0253                 China   CN  CHN
# 44506    Zhuzhou  32.174206  113.1469                 China   CN  CHN
# 44511       Zibo  36.783100  118.0497                 China   CN  CHN
# 44517     Zigong  29.349800  104.7645                 China   CN  CHN
# 44629      Zunyi  27.705000  106.9336                 China   CN  CHN
#
#        population
# 19        1530000
# 83        4980000
# 121       1483000
# 131       3770000
# 169       2388000
# ...           ...
# 44496     7231234
# 44506     4020800
# 44511     2631647
# 44517     2678899
# 44629     6606675
#
# [767 rows x 7 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# محاسبه فاصله
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# می‌خواهیم فاصله هر یک از شهر‌ها را از تهران حساب کنیم. برای این کار از فرمول هاورسین استفاده خواهیم کرد. این فرمول بر اساس طول جغرافیایی (Logitude) و عرض جغرافیایی (Latitude)  دو نقطه در سطح یک کره، فاصله آنها را حساب می‌کند.
# فرمول محاسبه فاصله هاورسین در ادامه آورده شده است.
# خواسته ما این است که اول با توجه به فرمول هاورسین و مقادیر طول و عرض جغرافیایی تهران که از دیتافریم استخراج می‌کنید تابعی بنویسید که فاصله هر شهر را از تهران محاسبه کند و سپس با استفاده از آن تابع ستون جدیدی در دیتافریم ایجاد کنید که فاصله هر شهر از تهران را داشته باشد
# </font>
# </p>
#
# </div>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# فرمول هاورسین:
# </font>
# </p>
#
#
#
# $\lambda_1$, $\lambda_2$ : longitudes of the two points in radians (lng)
#
# $\varphi_1$, $\varphi_2$ : the latitudes of the two points in radians (lat)
#
# $d$ : distance between two cities
#
#
# $$
# r = 6371
# $$
# $$
# a = \sin^2\left(\frac{\varphi_2-\varphi_1}{2}\right) + \cos(\varphi_1)\cos(\varphi_2)\sin^2\left(\frac{\lambda_2-\lambda_1}{2}\right)
# $$
# $$
# d = 2r \operatorname{atan2}\left(\sqrt{a}, \sqrt{1 -a}\right)
# $$
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# <code>تذکر:</code>
# دقت کنید که مقادیر طول و عرض جغرافیایی ثبت شده در دیتافریم به درجه می‌باشد و برای استفاده از رابطه فوق باید به رادیان تبدیل گردد. همچنین توجه کنید ملاک ارزیابی پاسخ شما فرمول فوق و طول و عرض جغرافیایی تهران که در همین دیتافریم درج شده، می‌باشد.
# </font>
# </p>

# %%
# distance function 
# Define the Haversine formula
import numpy as np
def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])
    
    # Radius of the Earth in kilometers
    R = 6371.0
    
    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c

    return distance

# %%
# add a new column in DataFrame 
tehran_lat = data[data['city'] == 'Tehran']['lat'].values[0]
tehran_lon = data[data['city'] == 'Tehran']['lng'].values[0]

data['distance_from_tehran'] = data.apply(lambda row: haversine(tehran_lat, tehran_lon, row['lat'], row['lng']), axis=1)

data
# Out:
#             city        lat       lng               country iso2 iso3  \
# 19           Aba   5.116700    7.3667               Nigeria   NG  NGA
# 83       Abidjan   5.316700   -4.0333         Côte d'Ivoire   CI  CIV
# 121    Abu Dhabi  24.466700   54.3667  United Arab Emirates   AE  ARE
# 131        Abuja   9.066700    7.4833               Nigeria   NG  NGA
# 169        Accra   5.550000   -0.2000                 Ghana   GH  GHA
# ...          ...        ...       ...                   ...  ...  ...
# 44496  Zhumadian  32.977300  114.0253                 China   CN  CHN
# 44506    Zhuzhou  32.174206  113.1469                 China   CN  CHN
# 44511       Zibo  36.783100  118.0497                 China   CN  CHN
# 44517     Zigong  29.349800  104.7645                 China   CN  CHN
# 44629      Zunyi  27.705000  106.9336                 China   CN  CHN
#
#        population  distance_from_tehran
# 19        1530000           5634.737243
# 83        4980000           6575.533770
# 121       1483000           1280.150009
# 131       3770000           5331.673578
# 169       2388000           6230.918394
# ...           ...                   ...
# 44496     7231234           5659.546660
# 44506     4020800           5616.330650
# 44511     2631647           5851.598592
# 44517     2678899           4993.215896
# 44629     6606675           5260.416825
#
# [767 rows x 8 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# مرتب سازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# شهرها را بر اساس حروف الفبا به صورت صعودی مرتب نمایید و سپس بر اساس مقدار ستون
# <code>
# lat
# </code>
# به صورت نزولی مرتب کرده
# </font>
# </p>
#
# </div>

# %%
# Sorting

data.sort_values(by=['city', 'lat'], ascending=[True, False], inplace=True)

# Reset the index
data.reset_index(drop=True, inplace=True)

data
# Out:
#           city      lat       lng               country iso2 iso3  population  \
# 0          Aba   5.1167    7.3667               Nigeria   NG  NGA     1530000
# 1      Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV     4980000
# 2    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE     1483000
# 3        Abuja   9.0667    7.4833               Nigeria   NG  NGA     3770000
# 4        Accra   5.5500   -0.2000                 Ghana   GH  GHA     2388000
# ..         ...      ...       ...                   ...  ...  ...         ...
# 762     Ürümqi  43.8225   87.6125                 China   CN  CHN     4335017
# 763       Āgra  27.1800   78.0200                 India   IN  IND     1585704
# 764      İzmir  38.4200   27.1400                Turkey   TR  TUR     4320519
# 765      Ōsaka  34.6939  135.5022                 Japan   JP  JPN    15126000
# 766  Şanlıurfa  37.1583   38.7917                Turkey   TR  TUR     1985753
#
#      distance_from_tehran
# 0             5634.737243
# 1             6575.533770
# 2             1280.150009
# 3             5331.673578
# 4             6230.918394
# ..                    ...
# 762           3197.472953
# 763           2687.466060
# 764           2166.791444
# 765           7381.949949
# 766           1138.007632
#
# [767 rows x 8 columns]

# %% [markdown]
# azza<div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# ذخیره سازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# دیتافریم مرتب شده را بدون نمایه‌هایش (index) در فایلی به فرمت روبه‌رو ذخیره کنید
#
# <code>
# StudentNumber.csv
# </code>
# <p style=color:yellow>
# شماره دانشجویی خودتان را جایگزین StudentNumber کنید
# </p>
# </font>
# </p>
#
# </div>

# %%
# Save CSV file
data.to_csv('9931096.csv', index=False)

# %% [markdown]
# <div align=center>
#     <img src="image-2.png" alt="Alt text">
# </div>
# <div align=center>
#     <p dir="rtl">3 سطر اول فایل شما باید به صورت فوق باشد</p>
# </div>

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# مصور سازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این قسمت نموداری رسم کنید که فاصله 10 شهری که کمترین فاصله را از تهران دارند را در قالب یک bar chart نمایش دهد.
# </font>
# <br>
# نمودار خروجی خود را به فرمت روبه‌رو ذخیر کنید:
# <code> plot_1.png </code>
# </p>
#
# </div>

# %%
# 10 Nearest Cities to Tehran
import matplotlib.pyplot as plt

# Sort the DataFrame by distance from Tehran
data.sort_values(by='distance_from_tehran', inplace=True)

# Get the top 10 cities (shortest distance)
top_10_cities = data.head(10)

# Create a Bar Chart
plt.figure(figsize=(12, 6))
plt.bar(top_10_cities['city'], top_10_cities['distance_from_tehran'], color='skyblue')
plt.xlabel('City Name')
plt.ylabel('Distance from Tehran (kilometers)')
plt.title('10 Cities with the Shortest Distance from Tehran')
plt.xticks(rotation=45, ha="right")

# Save the chart as a PNG image
plt.savefig('plot_1.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در قسمت بعدی می‌خواهیم جمعیت 10 شهری که کمترین فاصله را با تهران دارند را رسم نمایید.
# <br>
# نمودار خروجی خود را به فرمت روبه‌رو ذخیر کنید:
# <code> plot_2.png </code>
# </font>
# </p>

# %%
# Population of the 10 Nearest Cities to Tehran
import matplotlib.pyplot as plt

# Sort the DataFrame by distance from Tehran
data.sort_values(by='distance_from_tehran', inplace=True)

# Get the top 10 cities (shortest distance)
top_10_cities = data.head(10)

# Create a bar chart for population
plt.figure(figsize=(12, 6))
plt.bar(top_10_cities['city'], top_10_cities['population'], color='lightcoral')
plt.xlabel('City Name')
plt.ylabel('Population')
plt.title('Population of 10 Cities with the Shortest Distance from Tehran')
plt.xticks(rotation=45, ha="right")

# Save the chart as a PNG image
plt.savefig('plot_2.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در قسمت آخر میخواهیم نمودار Scatter ای رسم کنید که محور افقی آن Longtitude و محور عمودی آن Latitude باشد.
# </font>
# خروجی نهایی این نمودار با توجه به حجم بالای دیتاست بسیار جالب است.
#
# <br>
# نمودار خروجی خود را به فرمت روبه‌رو ذخیر کنید:
# <code> plot_3.png </code>
# </p>

# %%
# City Latitudes and Longitudes
import matplotlib.pyplot as plt

# Create a Scatter plot for longitude (x) and latitude (y)
plt.figure(figsize=(12, 8))
plt.scatter(data['lng'], data['lat'], s=10, c='blue', alpha=0.5)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Distribution of Cities')
plt.grid()

# Save the Scatter plot as a PNG image
plt.savefig('plot_3.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:green">
# بخش امتیازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# هر نوع مصور سازی دیگر و یا تحلیل و کار با داده در صورتی که به فهم بهتر داده کمک کند نمره امتیازی خواهد داشت.
# </p>
#
# </div>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(data['population'], bins=20, color='lightblue', edgecolor='black')
plt.xlabel('Population')
plt.ylabel('Number of Cities')
plt.title('Distribution of City Populations')
plt.grid()

plt.savefig('population_histogram.png', bbox_inches='tight')

average_population = data['population'].mean()
print(f"Average Population: {average_population:.2f}")

most_populous_city = data[data['population'] == data['population'].max()]
print(f"Most Populous City: {most_populous_city['city'].values[0]} with a population of {most_populous_city['population'].values[0]}")
# Out:
# Average Population: 3488894.76
# Most Populous City: Tokyo with a population of 37732000
